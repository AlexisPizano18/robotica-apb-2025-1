# %% [markdown]
# # Práctica 1 URDF
#
#
# | Código | Description |
# | ------:| ----------- |
# | ***Asignatura*** | |
# | **Robotica-2025-I**  | Práctica *01* |
#
# ## Contenido
#
# - [Objetivo](#objetivo)
# - [Introducción](#introduccion)
# - [Previo](#previo)
# - [Desarrollo](#desarrollo)
# - [Conclusiones](#conclusiones)
# - [Autor](#autor)
# - [Referencias](#referencias)
#
# ## Objetivo
#
# El objetivo de esta práctica es que el alumno comprenda, interprete y modifique la información básica de los formatos de Universal Robot Description File (URDF).
#
# ## Introducción
#
# La Práctica 1 tiene como objetivo principal que los estudiantes se familiaricen con los elementos clave del **Robot Operating System 2 (ROS 2)**, y el **Unified Robot Description Format (URDF)**, herramientas fundamentales para la descripción y simulación de robots en ambientes virtuales. A lo largo de esta práctica, se investigan y aplican conceptos esenciales como la definición de URDF, los tipos de juntas o articulaciones que se pueden especificar en dicho formato, y los elementos geométricos primitivos utilizados para modelar un robot. Además, la práctica aborda el uso de **nodos y tópicos en ROS 2**, componentes esenciales para la comunicación y la sincronización de tareas en sistemas robóticos distribuidos. Asimismo, se introduce a los estudiantes a **RVIZ**, una herramienta gráfica en 3D utilizada para la visualización de robots y sus entornos, permitiendo la interpretación visual de las acciones y movimientos simulados. Con esta práctica, se busca que los estudiantes comprendan cómo describir un robot de manera precisa en un entorno ROS 2, facilitando el desarrollo de simulaciones avanzadas y la implementación de proyectos en robótica.
#
# ### **Previo de la Práctica 1**
#
# ### **Definición de URDF**
# El Unified Robot Description Format (URDF) es un formato de archivo basado en XML utilizado en ROS (Robot Operating System) para describir la estructura física de un robot. Este archivo especifica la geometría, las articulaciones y los enlaces del robot, lo que permite su visualización y simulación en herramientas como RVIZ o Gazebo. Los URDF son esenciales para definir cómo un robot está construido y cómo se mueve, proporcionando un marco estandarizado para la descripción de robots en simulaciones o implementaciones físicas.
#
# ### **Tipos de Juntas en el Formato URDF**
# Dentro de un archivo URDF, se pueden definir varios tipos de juntas o articulaciones, cada una con diferentes características de movimiento. Los tipos más comunes son:
# * Revolute Joint (Junta Revoluta): Permite la rotación entre dos enlaces alrededor de un eje específico, con un límite de ángulo definido. Es el tipo más común de junta en robots que necesitan rotación controlada, como los brazos robóticos.
# * Prismatic Joint (Junta Prismática): Permite el movimiento lineal entre dos enlaces a lo largo de un eje, con un límite de desplazamiento. Es utilizado en actuadores lineales.
# * Continuous Joint (Junta Continua): Similar a la junta revoluta, pero permite rotación continua sin límite de ángulo. Este tipo de junta es común en ruedas que requieren rotación ilimitada.
# * Fixed Joint (Junta Fija): No permite movimiento entre los enlaces. Se utiliza para unir dos enlaces que deben comportarse como una sola unidad sólida.
# * Floating Joint (Junta Flotante): Proporciona seis grados de libertad (tres traslacionales y tres rotacionales). Este tipo de junta permite movimiento en todas las direcciones, aunque es más compleja y no se utiliza comúnmente.
# * Planar Joint (Junta Plana): Permite movimientos en un plano bidimensional, es decir, permite dos grados de libertad traslacionales y un grado de libertad rotacional.
#
# ### **Elementos "Primitivos" para Definir un Robot en ROS**
# En ROS , el **URDF (Unified Robot Description Format)** permite describir la estructura física de un robot utilizando varios elementos clave que ayudan a modelar tanto la geometría como el comportamiento del robot.
# 1. **Links (Enlaces)**: Son las partes rígidas del robot, que pueden tener propiedades como masa, inercia y geometría. Cada link representa un componente físico del robot, como brazos o ruedas, y es esencial para definir su estructura.
# 2. **Joints (Articulaciones)**: Conectan los links y permiten movimiento. Los tipos principales incluyen **revolute** (rotación), **prismatic** (desplazamiento), y **fixed** (sin movimiento). Estos elementos son fundamentales para controlar cómo las diferentes partes del robot se mueven entre sí.
# 3.  **Geometría**: Define la forma física de los links mediante primitivas geométricas como cajas, cilindros, esferas y mallas 3D. Esto es importante tanto para la visualización en simuladores como para la interacción física del robot con su entorno.
# 4.  **Visual y Collision**: La sección **visual** especifica cómo se verá el robot en un simulador, mientras que la sección **collision** define cómo interactuará físicamente con otros objetos. Aunque ambas pueden compartir geometría, la de colisión suele ser más simplificada para optimizar el rendimiento.
# 5. **Inertial**: Define las propiedades dinámicas de cada link, como la masa y la distribución de la inercia. Esto es crucial para simular con precisión cómo el robot responderá a las fuerzas y movimientos aplicados. Para obtener una evaluación excelente en la investigación, es necesario presentar esta información de forma clara, sin errores gramaticales, y asegurando que esté bien organizada y sintética.
# ### **¿Qué es un Nodo y un Tópico en ROS 2?**
# En ROS 2, un nodo es una unidad de ejecución que realiza una tarea específica dentro de un sistema robótico. Cada nodo puede estar encargado de tareas como la lectura de sensores, el control de actuadores, o la planificación de movimientos. Los nodos pueden comunicarse entre sí para coordinar sus actividades.
#
# Un tópico en ROS 2 es un canal de comunicación asíncrono en el que los nodos pueden publicar o suscribirse para intercambiar datos. Un nodo que genera datos (como las lecturas de un sensor) publicará esa información en un tópico, mientras que otros nodos que necesiten esos datos se suscribirán al tópico para recibir la información.
#
# ### **¿Qué es RVIZ?**
# RVIZ es una herramienta de visualización 3D utilizada en ROS. Permite a los desarrolladores ver el estado de un robot y su entorno en tiempo real, incluyendo la geometría del robot, los datos de los sensores, los mapas de navegación y las trayectorias de movimiento. RVIZ es crucial para depurar y analizar el comportamiento de los robots durante las simulaciones o en aplicaciones del mundo real.
#
#
# ## Desarrollo
#
# El desarrollo de la práctica se divide en dos partes:
#
# 1. La primera parte de realizará en clase, en la cual se desarrollará y simulará de descripción de un eslabón cayo movimiento está restringido por una junta rotacional.
#
# ![eslabon_1](Imagenes_P1/imagen1.png)
#
# Imagen 1. Simulación de Eslabón con Junta Rotacional en RViz.
#
# 2. El alumno debe modificar el código del archivo para agregar otro eslabón el cual puede estar unido al primer eslabón por una junta revolución o una junta prismática.
#
# ![eslabon_2](Imagenes_P1/imagen2.png)
#
# Imagen 2. Simulación de un Robot con Dos Eslabones y Junta Primática.
#
# ### -Definición del robot y del enlace con el mundo:
# ```xml
# <robot name="basic_link">
#     <link name="world">
#     </link>
# ```
# Aquí se define el robot llamado `basic_link` y se crea un enlace (`link`) llamado `world`, que representa el entorno o la base del robot, es decir, un punto de referencia fijo.
#
# ### -Unión entre el mundo y el enlace base:
# ```xml
# <joint name="world_to_base_link" type="fixed">
#     <parent link="world"/>
#     <child link="base_link"/>
#     <origin xyz="0.0 0.0 0.0" rpy="0.0 0.0 0.0"/>
# </joint>
# ```
# Se define una junta fija entre el `world` y el enlace base (`base_link`). Esto significa que el `base_link` no tendrá movimiento respecto al mundo. La posición y la orientación de la junta están en el origen (0,0,0) para ambos sistemas de coordenadas.
#
# ### -Definición del enlace base:
# ```xml
# <link name="base_link">
#     <visual>
#         <origin xyz="0.0 0.0 0.075" rpy="0.0 0.0 0.0"/>
#         <geometry>
#             <box size="0.1 0.12 0.15"/>
#         </geometry>
#         <material name="grey">
#             <color rgba="0.5 0.5 0.5 1.0" />
#         </material>
#     </visual>
#     <collision>
#         <origin xyz="0.0 0.0 0.075" rpy="0.0 0.0 0.0"/>
#         <geometry>
#             <box size="0.1 0.12 0.15"/>
#         </geometry>
#     </collision>
#     <inertial>
#         <mass value="0.5"/>
#         <origin xyz="0.0 0.0 0.0" rpy="0.0 0.0 0.0"/>
#         <inertia ixx="0.1" ixy="0.0" ixz="0.0" iyy="1.0" iyz="0.0" izz="1.0"/>
#     </inertial>
# </link>
# ```
# En esta parte se define el `base_link`, que tiene tres aspectos importantes:
#
# 1. **Visual**: Describe cómo se verá este enlace, con un origen de (0.0, 0.0, 0.075), una forma geométrica de caja con dimensiones `0.1 x 0.12 x 0.15` y un color gris.
# 2. **Colisión**: Define la geometría para el cálculo de colisiones, que es igual a la parte visual.
# 3. **Inercial**: Define la masa del enlace (0.5 kg) y su tensor de inercia, que influye en cómo el enlace reacciona al movimiento.
#
# ### -Definición del primer eslabón y la unión:
# ```xml
# <link name="link_1">
#     <visual>
#         <origin xyz="0.025 0.0 0.25" rpy="0.0 0.0 0.0"/>
#         <geometry>
#             <box size="0.05 0.05 0.5"/>
#         </geometry>
#         <material name="green">
#             <color rgba="0.0 0.8 0.0 1.0" />
#         </material>
#     </visual>
#     <collision>
#         <origin xyz="0.025 0.0 0.25" rpy="0.0 0.0 0.0"/>
#         <geometry>
#             <box size="0.05 0.05 0.5"/>
#         </geometry>
#     </collision>
#     <inertial>
#         <mass value="0.3"/>
#         <origin xyz="0.0 0.0 0.0" rpy="0.0 0.0 0.0"/>
#         <inertia ixx="0.1" ixy="0.0" ixz="0.0" iyy="1.0" iyz="0.0" izz="1.0"/>
#     </inertial>
# </link>
#
# <joint name="base_link_to_link_1" type="revolute">
#     <parent link="base_link"/>
#     <child link="link_1"/>
#     <axis xyz="1 0 0"/>
#     <limit lower="-3.14159" upper="3.14159" velocity="50.0" effort="1000.0"/>
#     <origin xyz="0.05 0 0.15" rpy="0 0 0"/>
# </joint>
# ```
# Aquí se define el `link_1`, con propiedades similares al `base_link`. Es una caja más delgada y alta, de color verde, con una masa de 0.3 kg. Además, se define una junta `revolute` entre `base_link` y `link_1`, lo que permite que el `link_1` gire en torno al eje `x`.
#
# ### -Definición del segundo eslabón y la unión:
# ```xml
# <link name="link_2">
#     <visual>
#         <origin xyz="0.025 0.00 0.25" rpy="0.0 0.0 0.0"/>
#         <geometry>
#             <box size="0.05 0.05 0.5"/>
#         </geometry>
#         <material name="blue_2">
#             <color rgba="0.0 0.14 0.57 1.0" />
#         </material>
#     </visual>
#     <collision>
#         <origin xyz="0.025 0.05 0.25" rpy="0.0 0.0 0.0"/>
#         <geometry>
#             <box size="0.05 0.05 0.5"/>
#         </geometry>
#     </collision>
#     <inertial>
#         <mass value="0.3"/>
#         <origin xyz="0.0 0.0 0.0" rpy="0.0 0.0 0.0"/>
#         <inertia ixx="0.1" ixy="0.0" ixz="0.0" iyy="1.0" iyz="0.0" izz="1.0"/>
#     </inertial>
# </link>
#
# <joint name="link_1_to_link_2" type="revolute">
#     <parent link="link_1"/>
#     <child link="link_2"/>
#     <axis xyz="1 0 0"/>
#     <limit lower="-3.14159" upper="3.14159" velocity="50.0" effort="1000.0"/>
#     <origin xyz="0.05 0 0.5" rpy="0 0 0"/>
# </joint>
# ```
# Este es el `link_2`, similar al `link_1`, pero de color azul. La junta `link_1_to_link_2` permite que el `link_2` gire en torno al eje `x`, con límites de movimiento y velocidades especificadas.
#
# ### -Definiciones específicas para Gazebo:
# ```xml
# <gazebo reference="base_link">
#     <material>Gazebo/Grey</material>
# </gazebo>
#
# <gazebo reference="link_1">
#     <material>Gazebo/Red</material>
# </gazebo>
# ```
# Estas líneas especifican los materiales visuales que usará Gazebo para simular el robot, asignando el color gris para el `base_link` y rojo para el `link_1`.
#
# ### -Definición del control del robot:
# ```xml
# <transmission name ="trans_1">
#     <type>transmission_interface/SimpleTransmission</type>
#     <joint name="base_link_to_link_1">
#         <hardwareInterface>hardware_interface/PositionJointInterface</hardwareInterface>
#     </joint>
#     <actuator name="motor_1">
#         <hardwareInterface>hardware_interface/PositionJointInterface</hardwareInterface>
#         <mechanicalReduction>1</mechanicalReduction>
#     </actuator>
# </transmission>
# ```
# Define una transmisión para el control del robot, especificando que el `base_link_to_link_1` está controlado por un actuador (`motor_1`) a través de una interfaz de posición.
#
# ### -Plugins de Gazebo:
# ```xml
# <gazebo>
#     <plugin name="joint_state_publisher_controller"
#             filename="libgazebo_ros_joint_state_publisher.so">
#         <update_rate>10</update_rate>
#         <joint_name>base_link_to_link_1</joint_name>
#     </plugin>
# </gazebo>
#
# <gazebo>
#     <plugin name="joint_pose_trajectory_controller"
#             filename="libgazebo_ros_joint_pose_trajectory.so">
#         <update_rate>2</update_rate>
#     </plugin>
# </gazebo>
# ```
# Se definen dos plugins de control para Gazebo:
#
# joint_state_publisher_controller: Publica el estado de la junta `base_link_to_link_1` a una tasa de actualización de 10 Hz.
# joint_pose_trajectory_controller: Controla la trayectoria de la pose de la junta a 2 Hz.
#
#
# ## Resultados
#
# ![eslabon_3](Imagenes_P1/imagen3.png )
#
# Imagen 3. Simulación en RViz mostrando el modelo del robot manipulado con dos eslabones conectados por una junta revoluta y una junta prismática. La configuración permite visualizar la interacción y movimiento de las partes modeladas en URDF dentro del entorno de simulación.
#
#
#
#
#
# [![practica 1](https://img.youtube.com/vi/BdgZefz2JEg/0.jpg)](https://www.youtube.com/watch?v=BdgZefz2JEg)
#
# Miniatura del video mostrando el funcionamiento del robot en el simulador RViz, donde se visualiza el movimiento de los eslabones y juntas programadas en URDF, permitiendo la interacción y manipulación dentro del entorno virtual.
#
#
#
# ## Conclusiones
#
# Al finalizar la Práctica 1, se adquirió un conocimiento fundamental sobre la estructura y el uso del Universal Robot Description Format (URDF) dentro del entorno de ROS 2. Los objetivos planteados se cumplieron de manera efectiva, ya que se comprendió el orden y la organización de los archivos que conforman los espacios de trabajo en ROS 2. Además, se logró modificar la descripción de un robot serial utilizando archivos URDF y se pudo añadir una segunda junta móvil, lo que permitió expandir las capacidades de simulación del robot y observar un comportamiento más complejo en sus movimientos. Asimismo, se utilizó la herramienta RVIZ para visualizar las configuraciones robóticas, lo que facilitó una mejor interpretación de la cinemática y el comportamiento del robot. Finalmente, se aprendió a trabajar con los elementos básicos de un archivo launch, lo que permite lanzar y controlar simulaciones de manera eficiente. Esta práctica brindó las herramientas necesarias para abordar simulaciones más complejas y continuar desarrollando habilidades en el manejo de robots en ROS 2.
#
# ## Autor
#
# | Iniciales  | Description |
# | ----------:| ----------- |
# |**Autor** |Pizano Bravo Alexis [GitHub profile](https://github.com/AlexisPizano18) |
# | **RICF** | Felipe Rivas Campos [GitHub profile](https://github.com/rivascf) |
# | **EPM**  | Erik Peña Medina [GitHub profile](https://github.com/ErikFiUNAM) |
# | **MGR-MX** | Mechatronics Research Group, México [GitHub profile](https://github.com/mrg-mx) |
#
# ## Referencias
#
# <a id="1">[1]</a>URDF XML Format," Robot Operating System Wiki. [Online]. Available: http://wiki.ros.org/urdf/XML. Accessed: Sep. 28, 2024.
#
# <a id="2">[2]</a>"Understanding ROS 2 Topics," ROS 2 Documentation. [Online]. Available: https://docs.ros.org/en/foxy/Tutorials/Understanding-ROS2-Topics.html. Accessed: Sep. 28, 2024.
#
# <a id="3">[3]</a>"RVIZ," Robot Operating System Wiki. [Online]. Available: http://wiki.ros.org/rviz. Accessed: Sep. 28, 2024.
#
# <a id="4">[4]</a>"URDF XML Format," Robot Operating System Wiki. [Online]. Available: http://wiki.ros.org/urdf/XML. Accessed: Sep. 28, 2024.
#
# <a id="5">[5]</a>"Robot Geometry Primitives in URDF," ROS Documentation. [Online]. Available: https://wiki.ros.org/urdf/XML/link. Accessed: Sep. 28, 2024.
